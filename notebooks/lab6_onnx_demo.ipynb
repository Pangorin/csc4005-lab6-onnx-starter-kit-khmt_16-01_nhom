# %% [markdown]
# # CSC4005 Lab 6 Demo – Export ONNX + Consistency Test + Benchmark
#
# Notebook này chỉ đóng vai trò minh họa. Khi làm bài chính, nên chạy bằng terminal để dễ lưu log và artefact.

# %% [markdown]
# ## 1. Export ONNX
#
# ```bash
# python -m src.export_onnx --checkpoint checkpoints/best_model.pt --onnx_path outputs/vit_smartcampus.onnx --dynamic_batch
# ```

# %% [markdown]
# ## 2. Consistency Test
#
# ```bash
# python -m src.consistency_test --checkpoint checkpoints/best_model.pt --onnx_path outputs/vit_smartcampus.onnx --data_dir data/mit_indoor_smartcampus_5
# ```

# %% [markdown]
# ## 3. Benchmark
#
# ```bash
# python -m src.benchmark --checkpoint checkpoints/best_model.pt --onnx_path outputs/vit_smartcampus.onnx --batch_sizes 1 4 8 --warmup 10 --repeat 50
# ```

# %%
from pathlib import Path
print(Path.cwd())
